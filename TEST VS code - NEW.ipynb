# %%
# First let's install the required packages and modules
# Only to run in specific cases, not needed for the final version of the code
# %pip install pycryptodome
# %pip install cryptography
# %pip install hashlib
# %pip install requests
# %pip install tqdm
# %pip install forex-python==1.5
# %pip install yfinance==0.2.12
# %pip install requests pandas
# %pip install pandas openpyxl

# %%
# %pip install pandas openpyxl

# %% [markdown]
# What is done :
# - Reteive all financial transaction on HIVE layer 1 blockchain
# - Store these transaction in a standardized way on google drive / excel file
# - Able to source all outgoing transaction on HIVE L2 (moslty OCLT)
#
# Problem:
# - Not able to source incoming transaction on L2 blockchain. Idk why but we can't see on HIVE blockexplored incoming OCLT transaction - see the last transaciton from paulo21 to ocln-finacct, sent 0.2 OCLT, and there is no log on ocln-finacct transactions list.... ?
#   - To solve this we need to access L2 API (HIVE engine), no ideas yet how to do it.
#   - Something arrise : On L2 transaction (custon JSON), when placing a sell / buy order this generate a transaction - which need to be ignored for the time being
#
#
# Next steps:
# - List all OCL Hive accounts, to gather all transaction
# - add a field, in the panda dataframe indicating the name of the source wallet, from where we extract the data (for intercompany transactions)
# - Find a way to extract L2 transaction using HIVE engine / VLS or....
# - Define acounting scheme per type of transaction to automate accounting entries generation
# - source FX rates (idk why but Yahoo finance does not work)
# - tbd...

# %%
# %pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %%
# %pip install -U beem
# %pip install pyhive

# %%
# %pip install thrift
# %pip install sasl
# %pip install thrift
# %pip install thrift-sasl
# %pip install PyHive

# %%
# import all the required libraries
from beem import Hive
from beem.nodelist import NodeList
from beem import Hive
from beem.account import Account
import pandas as pd
from beem.account import Account
from beem.comment import Comment
from beem.exceptions import ContentDoesNotExistsException
from datetime import datetime
import ast
from tqdm import tqdm
import json
from beem.account import Account
import ast
import os

# %%
# get the current list of active nodes
nodelist = NodeList()
nodelist.update_nodes()
nodes = nodelist.get_hive_nodes()
hive = Hive(node=nodes)
print(hive.is_hive)
# Out:
# True

# %%
# Initialize the wallet
hive = Hive()
account = Account("paulo21", blockchain_instance=hive)
hive.wallet.wipe(True)
hive.wallet.unlock("passphrase")

# %%
# Def function to convert currency
def convert_currency(_currency):
  if _currency == "@@000000013":
    return "hbd"
  elif _currency == "@@000000021":
    return "hive"
  else:
    return "Error parsing currency"

# %%
# Def function to convert json into pandas dataframe
def json_to_dataframe(json):
  df = pd.DataFrame(json)
  return df

# %%
# Def function to get all transactions from one account and return a dataframe
def get_all_account_transactions(account_name):
  
  account = Account(account_name, blockchain_instance=hive)

  list_of_transactions_dict = account.history()
  list_of_transactions_dataframe = json_to_dataframe(list_of_transactions_dict)

  return list_of_transactions_dataframe

# %%
#enter the name of the account you want to check
#hive = Hive()
#account = Account("paulo21", blockchain_instance=hive)



# Def a function, which extract all transfer type of transaction for an individual account
def get_transaction_transfer(account_name):

  account = Account(account_name, blockchain_instance=hive)

  total_transactions = len(list(account.history(only_ops=["transfer_from_savings", "transfer_to_savings", "transfer", "claim_reward_balance", "account_create"])))

  transaction_ledger = pd.DataFrame(columns=[    "_date",    "_type",    "_from",    "_memo",    "_to",    "_block",
                                             "_trx_id",    "_id",    "_index",    "_amount_out",    "_amount_in",
                                                 "_currency_out","_currency_in",    "_precision_out",    "_precision_in",
                                                 "_virtual_op", "_key_auths", "_new_account_name"])

#  for trans in account.history():

#    print(trans)


  for trans in tqdm(account.history(only_ops=["transfer_from_savings", "transfer_to_savings", "transfer", "claim_reward_balance",
                                         "account_create"]), total=total_transactions, desc="Processing transactions except collateral"): #two arguments in the only_ops does not work...

    print(trans)

    # Convert date text to date format
    dateString = trans["timestamp"]
    dateformat = "%Y-%m-%dT%H:%M:%S"

    try:
      _date = datetime.strptime(dateString, dateformat)
    except ValueError:
      _date = "Error parsing date format"

    _type = trans["type"]

    if _type in ["transfer_from_savings", "transfer_to_savings", "transfer"]:
      _from = trans["from"]
      _memo = trans["memo"]
      _to = trans["to"]
      _block = trans["block"]
      _trx_id = trans["trx_id"]
      _id = trans["_id"]
      _index = trans["index"]
      _virtual_op = trans["virtual_op"]
      _key_auths = ""
      _new_account_name = ""

      if _from == account_name and _to != account_name :
        _amount_out = int(trans["amount"]["amount"])
        _amount_in = 0
        _currency_out = convert_currency(trans["amount"]["nai"])
        _currency_in = ""
        _precision_out = int(trans["amount"]["precision"])
        _precision_in = 0
        _amount_out = _amount_out / (10**_precision_out)

      elif _from != account_name and _to == account_name :
        _amount_in = int(trans["amount"]["amount"])
        _amount_out = 0
        _currency_in = convert_currency(trans["amount"]["nai"])
        _currency_out = ""
        _precision_in = int(trans["amount"]["precision"])
        _precision_out = 0
        _amount_in = _amount_in / (10**_precision_in)

      elif _from == account_name and _to == account_name :
          _amount_out = int(trans["amount"]["amount"])
          _amount_in = int(trans["amount"]["amount"])
          _currency_out = convert_currency(trans["amount"]["nai"])
          _currency_in = convert_currency(trans["amount"]["nai"])
          _precision_in = int(trans["amount"]["precision"])
          _precision_out = int(trans["amount"]["precision"])
          _amount_in = _amount_in / (10**_precision_in)
          _amount_out = _amount_out / (10**_precision_out)

      transaction_ledger.loc[len(transaction_ledger)] = [_date, _type, _from, _memo, _to, _block, _trx_id, _id,
                                                       _index, _amount_out, _amount_in, _currency_out, _currency_in,
                                                       _precision_out, _precision_in, _virtual_op, _key_auths, _new_account_name ]


    elif _type == "account_create":
      _from = trans["account"]
      _memo = trans["memo_key"]
      _to = ""
      _block = trans["block"]
      _trx_id = trans["trx_id"]
      _id = trans["_id"]
      _index = trans["index"]
      _amount_in = 0
      _currency_out = convert_currency(trans["fee"]["nai"])
      _currency_in = ""
      _precision_out = int(trans["fee"]["precision"])
      _precision_in = 0
      _amount_out = int(trans["fee"]["amount"]) / (10**_precision_out)
      _virtual_op = trans["virtual_op"]
      _key_auths = (trans["active"]["key_auths"])[0]
      _new_account_name = trans["new_account_name"]

      transaction_ledger.loc[len(transaction_ledger)] = [_date, _type, _from, _memo, _to, _block, _trx_id, _id,
                                                       _index, _amount_out, _amount_in, _currency_out, _currency_in,
                                                       _precision_out, _precision_in, _virtual_op, _key_auths, _new_account_name ]

    elif _type == "claim_reward_balance":
      _from = ""
      _memo = ""
      _to = trans["account"]
      _block = trans["block"]
      _trx_id = trans["trx_id"]
      _id = trans["_id"]
      _index = trans["index"]
      _key_auths = ""
      _new_account_name = ""
      _virtual_op = trans["virtual_op"]
      _amount_in_hbd = int(trans["reward_hbd"]["amount"])
      _amount_in_hive = int(trans["reward_hive"]["amount"])
      _currency_out = ""
      _currency_in_hbd = "hbd"
      _currency_in_hive = "hive"
      _precision_out = 0
      _precision_in_hbd = int(trans["reward_hbd"]["precision"])
      _precision_in_hive = int(trans["reward_hive"]["precision"])
      _amount_in_hbd = _amount_in_hbd / (10**_precision_in_hbd)
      _amount_in_hive = _amount_in_hive / (10**_precision_in_hive)
      _amount_out = 0

      if _amount_in_hbd != 0:
        transaction_ledger.loc[len(transaction_ledger)] = [_date, _type, _from, _memo, _to, _block, _trx_id, _id,
                                                       _index, _amount_out, _amount_in_hbd, _currency_out, _currency_in_hbd,
                                                       _precision_out, _precision_in_hbd, _virtual_op, _key_auths, _new_account_name ]
      if _amount_in_hive != 0:
        transaction_ledger.loc[len(transaction_ledger)] = [_date, _type, _from, _memo, _to, _block, _trx_id, _id,
                                                       _index, _amount_out, _amount_in_hive, _currency_out, _currency_in_hive,
                                                       _precision_out, _precision_in_hive, _virtual_op, _key_auths, _new_account_name ]

  return transaction_ledger

wallet_name = "ocln-finacct"
transaction_ledger = get_transaction_transfer(wallet_name)

wallet_name2 = "paulo21"
transaction_ledger2 = get_transaction_transfer(wallet_name2)
# Out:
# Processing transactions except collateral: 0it [00:00, ?it/s]
# Processing transactions except collateral:   2%|▏         | 1/43 [00:00<00:33,  1.26it/s]
# {'amount': {'amount': '615822', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 90509710, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T15:56:36', 'trx_id': 'cee4a7359f5a83ff5411eb6ec141149c066bb9af', 'trx_in_block': 23, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '2989cbfe4d5643c517fe53e0d11cfc720f2f294d', 'index': 4}
# {'amount': {'amount': '1000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'to': 'ocl-paymaster', 'block': 90509850, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T16:03:36', 'trx_id': '1f357e10d04ea4e8d0cd10121a130c95805d4d23', 'trx_in_block': 25, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': 'ccfdedcb04d8ec1eb18626698de3a27344b55a86', 'index': 5}
# {'amount': {'amount': '565000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'to': 'ocl-paymaster', 'block': 90509875, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T16:04:51', 'trx_id': '9cfe0a6217606819c85d034789c9e6ec59fae681', 'trx_in_block': 12, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '6171b0f9e455bb4ac603e5941764408f21932d93', 'index': 6}
# {'amount': {'amount': '10000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'to': 'paulo21', 'block': 90509919, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T16:07:03', 'trx_id': 'be22edccee313ebff5abc23fe99535fb6b96e168', 'trx_in_block': 8, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer_to_savings', '_id': 'c902a1112e7ad1d4cca455f23184bd9c4ab7f370', 'index': 7}
# {'amount': {'amount': '20000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': 'f811cce4-76c1-4340-978a-4ae8bb00b04c', 'to': 'keychain.swap', 'block': 90509929, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T16:07:33', 'trx_id': 'c7e4e42a8cbe58167a1bb6daa614389ec81f8821', 'trx_in_block': 28, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': 'be84fc1482e848af16d4be1ea78342e8a56eae1e', 'index': 8}
# {'amount': {'amount': '3775', 'nai': '@@000000013', 'precision': 3}, 'from': 'keychain.swap', 'memo': 'Thank you for using our service (swap ID: f811cce4-76c1-4340-978a-4ae8bb00b04c)', 'to': 'paulo21', 'block': 90509933, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T16:07:45', 'trx_id': 'a85c2834c45a4f0479a757704894bebcbd83fca5', 'trx_in_block': 13, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '400eec3d144b2880fbb8959bd72c360affa200fd', 'index': 9}
# {'amount': {'amount': '3775', 'nai': '@@000000013', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'to': 'paulo21', 'block': 90509937, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T16:07:57', 'trx_id': '11fccecfbaa3c87ee6880c3bcbcbb4ba5af58698', 'trx_in_block': 10, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer_to_savings', '_id': '3a107d4f89410d8ea2a86ca7a0ccae3bbbbf2906', 'index': 10}
# {'amount': {'amount': '10000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'request_id': 1731082150, 'to': 'paulo21', 'block': 90509965, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-08T16:09:21', 'trx_id': 'd30535e3ea7e2620a098c8860bc8dba446154348', 'trx_in_block': 8, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer_from_savings', '_id': '16ac9e7da7947363463467992f8e2a65b2fed30f', 'index': 11}
# {'amount': {'amount': '1476', 'nai': '@@000000021', 'precision': 3}, 'from': 'honey-swap', 'memo': '{"id":"ssc-mainnet-hive","json":{"contractName":"hivepegged","contractAction":"removeWithdrawal","contractPayload":{"id":"858ba739dbb4a67d58066de2b3d25d7b0584f07e"}}}', 'to': 'paulo21', 'block': 90598192, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-11T17:47:54', 'trx_id': '05782461d2aa09efcf2c466356a896b192d28938', 'trx_in_block': 11, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '5a4c3cf2e21deef4630a80b456db5f3c3eb5334d', 'index': 19}
# {'amount': {'amount': '15000', 'nai': '@@000000013', 'precision': 3}, 'from': 'ocl-paymaster', 'memo': 'Welcome to OffChain Luxembourg asbl', 'to': 'paulo21', 'block': 90598529, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-11T18:04:48', 'trx_id': '5c6ae1a0326193e7e0de67c22630ed4ae53c44e0', 'trx_in_block': 7, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '54014ffad58e62dc9db7ceb43564385de0c8e0e4', 'index': 20}
# {'amount': {'amount': '286000', 'nai': '@@000000021', 'precision': 3}, 'from': 'shat92217', 'memo': "C'est bien mon grand tu fais la blockchain !", 'to': 'paulo21', 'block': 90603223, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-11T21:59:51', 'trx_id': '9227ebc68ec522be55c29d8edfd4395776dfb168', 'trx_in_block': 1, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '8ae9a844d69e0043c1385560c1c1da580bee6fc1', 'index': 21}
# {'amount': {'amount': '537992', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 90653278, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-13T15:46:39', 'trx_id': '73e7edecf3a9d307b291aa844912b734268e4b44', 'trx_in_block': 11, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': 'b4744a860eae5c964b9b00143672a5362e6820ff', 'index': 24}
# {'amount': {'amount': '1459068', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 90654375, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-13T16:41:36', 'trx_id': '63d8ae763cd9e58a8b76365f7e33a4ce7ac1549f', 'trx_in_block': 0, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '3e31d3d396ca697cf7b79ee34a8c442f0e93cfd8', 'index': 25}
# {'amount': {'amount': '3775', 'nai': '@@000000013', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'request_id': 1731521835, 'to': 'paulo21', 'block': 90656293, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-13T18:17:42', 'trx_id': '99d2989ddadab2063154e072713ef98443028143', 'trx_in_block': 12, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer_from_savings', '_id': 'f5c2b4526dd49f5a279c590a688d1232f6ff9dd6', 'index': 26}
# {'amount': {'amount': '200000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '{"id":"ssc-mainnet-hive","json":{"contractName":"hivepegged","contractAction":"buy","contractPayload":{}}}', 'to': 'honey-swap', 'block': 90657394, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-13T19:12:51', 'trx_id': '1fea28c94702ee511a54d85967cd139bd156f0ce', 'trx_in_block': 5, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '54ca7260bdc92fdc0998f673d9b33f04af6e06ed', 'index': 28}
# {'amount': {'amount': '1280355', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '101573283', 'to': 'bdhivesteem', 'block': 90762431, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-17T10:52:36', 'trx_id': '0c021215fda97178ee1add89dcaf7fd75b41c3c5', 'trx_in_block': 30, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '77c871cb3a61fc8e499088b4aeda4894a8b5a0c5', 'index': 41}
# {'active': {'account_auths': [], 'key_auths': [['STM6fdP73QDydvyntHUZ49nbv9ugzBSHZiy5snSCGdrqUTY4mMrZu', 1]], 'weight_threshold': 1}, 'creator': 'paulo21', 'fee': {'amount': '3000', 'nai': '@@000000021', 'precision': 3}, 'json_metadata': '{}', 'memo_key': 'STM67P9BR8Hr8LcvifZhxB7St4CyHYYkTcN8bEWbU2qT1ApBU8mzs', 'new_account_name': 'charleau123', 'owner': {'account_auths': [], 'key_auths': [['STM5314wuL9cDdpZGLdibivo4K3Fh1ncEsHkxp26wGBfCoooE2GBu', 1]], 'weight_threshold': 1}, 'posting': {'account_auths': [], 'key_auths': [['STM4wCGCoa1YtrEvoDsMhdrxXtS3VM2hqxNfVGi55iTspJiW16W7K', 1]], 'weight_threshold': 1}, 'block': 90913428, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-22T16:54:18', 'trx_id': '0ff32a75f301a55fad12c183c0c2fca390a0e9eb', 'trx_in_block': 8, 'virtual_op': False, 'account': 'paulo21', 'type': 'account_create', '_id': 'bd11b4b8064c8a54429d010092d0c7092f5f23f4', 'index': 45}
# {'amount': {'amount': '28169', 'nai': '@@000000013', 'precision': 3}, 'from': 'paulo21', 'memo': '3 guinness v4v-Q7c7c', 'to': 'indies.cafe', 'block': 90915317, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-22T18:28:51', 'trx_id': '9bf8a2972eec1861fc6cac95eed405f8992e1e7b', 'trx_in_block': 6, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': 'cefe3e51402d2744db0ebfd81e3886ba5e4a26eb', 'index': 48}
# {'amount': {'amount': '1500', 'nai': '@@000000013', 'precision': 3}, 'from': 'thedistriator', 'memo': 'You claimed back 15.00 % of payment (v4v-Q7c7c) & adding review of a Independent   Café - https://peakd.com/@paulo21/iqnxiajk', 'to': 'paulo21', 'block': 90915363, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-22T18:31:09', 'trx_id': '6e54cc4f8d6ba5bd16e02c5d1f7670c547c4299f', 'trx_in_block': 16, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '42979b8d07f6511a9681471995cad6b46a5a5e2a', 'index': 51}
# {'amount': {'amount': '28162', 'nai': '@@000000013', 'precision': 3}, 'from': 'paulo21', 'memo': 'v4v-zDndB', 'to': 'indies.cafe', 'block': 90915799, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-22T18:52:57', 'trx_id': '353e49201ba29130c0d5ff1ccc9c8340434fbe9f', 'trx_in_block': 9, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '41766350505fc65410f952a9d78e2a97912a516b', 'index': 52}
# {'amount': {'amount': '2000', 'nai': '@@000000013', 'precision': 3}, 'from': 'thedistriator', 'memo': 'You claimed back 20.00 % of payment (v4v-zDndB) & adding review of a Independent   Café - https://peakd.com/@paulo21/zxgwihxw', 'to': 'paulo21', 'block': 90915828, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-22T18:54:24', 'trx_id': 'e165e1ba6591c5d756fb3ece471496f67c9505b4', 'trx_in_block': 42, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': 'af86fc1ab295205ef9291c1de44669e3d5d90e25', 'index': 55}
# {'amount': {'amount': '271692', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '101573283', 'to': 'bdhivesteem', 'block': 90933311, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-23T09:29:57', 'trx_id': '001b3d5c9167867b6d8c86d164d6e1264f94dbc7', 'trx_in_block': 21, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '7c1b72d29bbb46d3e50026df99578336053c4341', 'index': 133}
# {'amount': {'amount': '176000', 'nai': '@@000000021', 'precision': 3}, 'from': 'honey-swap', 'memo': '{"id":"ssc-mainnet-hive","json":{"contractName":"hivepegged","contractAction":"removeWithdrawal","contractPayload":{"id":"34aae2467a2dd7527dba31aedd8cb301e5d663d1"}}}', 'to': 'paulo21', 'block': 91092810, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-11-28T22:41:57', 'trx_id': 'f53b95e37ce5e4a6b6e24f31c3337fab4e61390d', 'trx_in_block': 15, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': 'ce4cddb7376dbfa408bdb47b4475760a08271dae', 'index': 137}
# {'account': 'paulo21', 'reward_hbd': {'amount': '1803', 'nai': '@@000000013', 'precision': 3}, 'reward_hive': {'amount': '0', 'nai': '@@000000021', 'precision': 3}, 'reward_vests': {'amount': '10628042329', 'nai': '@@000000037', 'precision': 6}, 'block': 91171207, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-01T16:07:48', 'trx_id': '1ac969bc408a282b6e92f6675631bfcf68a50485', 'trx_in_block': 14, 'virtual_op': False, 'type': 'claim_reward_balance', '_id': '1b4e2248fc02e729a3365cb0ffa67fbdda1ceb92', 'index': 146}
# {'amount': {'amount': '2932298', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 91372254, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-08T16:20:15', 'trx_id': '5c1ab561e7872a0da738e7e179e4ef2d730fd64e', 'trx_in_block': 44, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': 'd07a68a800cbcc183eaeb8cd848b780a2d6829f1', 'index': 150}
# {'amount': {'amount': '2557768', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 91372800, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-08T16:47:36', 'trx_id': 'd41267fa253083b0bcffbc3120e41b235705883e', 'trx_in_block': 5, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '54a47fda7a775b2517f4f2c18a90886e4584587d', 'index': 155}
# {'amount': {'amount': '784163', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 91373105, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-08T17:02:54', 'trx_id': 'ea530e634b96ecd0d98e44c81bb9fa0202852842', 'trx_in_block': 15, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '8db79381c4ef3d12ecdfd7b34cfbacacf45db850', 'index': 158}
# {'amount': {'amount': '48685', 'nai': '@@000000013', 'precision': 3}, 'from': 'paulo21', 'memo': 'v4v-jxwXO', 'to': 'indies.cafe', 'block': 91462716, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-11T19:56:09', 'trx_id': 'f4d2496ada0f70e0931655828ef7d49319ddf471', 'trx_in_block': 7, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '9c55de8bb139657be6a0f4b4fe9ddc7f0882e9ef', 'index': 162}
# {'amount': {'amount': '2000', 'nai': '@@000000013', 'precision': 3}, 'from': 'thedistriator', 'memo': 'You claimed back 20.00 % of payment (v4v-jxwXO) & adding review of a Independent   Café - https://peakd.com/@paulo21/fljqcpga', 'to': 'paulo21', 'block': 91462761, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-11T19:58:24', 'trx_id': 'b7e020839e90e6e49aa76284f01d98003fb123fb', 'trx_in_block': 17, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '9e532cfa8db0b370c5508f68018546065b269755', 'index': 165}
# {'amount': {'amount': '3020000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '101573283', 'to': 'bdhivesteem', 'block': 91476506, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-12T07:26:42', 'trx_id': '45ac9f29c2776a7a4f470dfa22208ee4aec8a9e9', 'trx_in_block': 2, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '8e45ecd5a1b8119e2bb9cd4a520af6f1b894b2ed', 'index': 207}
# {'amount': {'amount': '1138990', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 91510264, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-13T11:36:36', 'trx_id': 'b952da64eb343eedff2c71eada058afad3c0cf3d', 'trx_in_block': 10, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '828455b4bd5e2702b2d9db8c881bfa01f1c1451b', 'index': 242}
# {'amount': {'amount': '100000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'to': 'paulo21', 'block': 91510289, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-13T11:37:51', 'trx_id': '8a8eca0ea8f35c492e5e8b591a396fe1910d5088', 'trx_in_block': 16, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer_to_savings', '_id': '91545badf8fcc6420a415af3b50d3f115c5f76ad', 'index': 243}
# {'amount': {'amount': '645060', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '101573283', 'to': 'bdhivesteem', 'block': 91685048, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-19T13:35:00', 'trx_id': 'e820d0c7d39e007209369c902c120146abaf4781', 'trx_in_block': 14, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '3ac3cc15da8ad9ef01ae2526f02dd25b08c32ae4', 'index': 260}
# {'amount': {'amount': '1', 'nai': '@@000000021', 'precision': 3}, 'from': 'arcange', 'memo': 'Thank you so much for your support to my witness! 🙇', 'to': 'paulo21', 'block': 91781714, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-22T22:13:18', 'trx_id': '46b4f75baceab20c3c52de7aaf552b68efbb4159', 'trx_in_block': 23, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '24b0665c12c999b9e30277e5d252279ef72a4b1b', 'index': 279}
# {'account': 'paulo21', 'reward_hbd': {'amount': '1058', 'nai': '@@000000013', 'precision': 3}, 'reward_hive': {'amount': '0', 'nai': '@@000000021', 'precision': 3}, 'reward_vests': {'amount': '6174727479', 'nai': '@@000000037', 'precision': 6}, 'block': 91781939, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-22T22:24:33', 'trx_id': '63e39f59626bce70667c02bb4f949d7577e77cad', 'trx_in_block': 2, 'virtual_op': False, 'type': 'claim_reward_balance', '_id': '9fe6493c50aa769742a985915976d63cc0d8d481', 'index': 328}
# {'amount': {'amount': '1', 'nai': '@@000000013', 'precision': 3}, 'from': 'paulo21', 'memo': '', 'to': 'paulo21', 'block': 91781998, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-22T22:27:30', 'trx_id': 'b2ccd27e3f8d743945803af24b36f43b30a40111', 'trx_in_block': 1, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer_to_savings', '_id': '8fa7d1c68afd9090df2305cc58a3f917430631f6', 'index': 330}
# {'amount': {'amount': '1056000', 'nai': '@@000000013', 'precision': 3}, 'from': 'paulo21', 'memo': 'Pledge for OCLT token development ', 'to': 'ocl-trez', 'block': 91840372, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-24T23:12:39', 'trx_id': '2eafd4cc79a849089b1506b89c9a762320bbf603', 'trx_in_block': 13, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '9be6ed8d838045ee47aa8cebf9ce00a1a319a936', 'index': 344}
# {'account': 'paulo21', 'reward_hbd': {'amount': '0', 'nai': '@@000000013', 'precision': 3}, 'reward_hive': {'amount': '0', 'nai': '@@000000021', 'precision': 3}, 'reward_vests': {'amount': '10159997', 'nai': '@@000000037', 'precision': 6}, 'block': 91926231, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-27T22:51:15', 'trx_id': 'c1edd20b0579f108e3ccc428246b5ef563894f96', 'trx_in_block': 7, 'virtual_op': False, 'type': 'claim_reward_balance', '_id': '36fb856e5bfb8a43f27fec7313c6b7d2c9355bb1', 'index': 349}
# {'account': 'paulo21', 'reward_hbd': {'amount': '0', 'nai': '@@000000013', 'precision': 3}, 'reward_hive': {'amount': '0', 'nai': '@@000000021', 'precision': 3}, 'reward_vests': {'amount': '10159254', 'nai': '@@000000037', 'precision': 6}, 'block': 91947688, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-28T16:45:21', 'trx_id': 'ba0d59940ff691347962411855dfd865e868fd9f', 'trx_in_block': 3, 'virtual_op': False, 'type': 'claim_reward_balance', '_id': '31281c2597498e00882758cd5741eead9999e6f3', 'index': 351}
# {'account': 'paulo21', 'reward_hbd': {'amount': '0', 'nai': '@@000000013', 'precision': 3}, 'reward_hive': {'amount': '0', 'nai': '@@000000021', 'precision': 3}, 'reward_vests': {'amount': '22011241', 'nai': '@@000000037', 'precision': 6}, 'block': 91966369, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-29T08:20:42', 'trx_id': 'cf858da421280e18e54a8c3de0a8cf9ce3b94359', 'trx_in_block': 7, 'virtual_op': False, 'type': 'claim_reward_balance', '_id': '1bf27dd00a5d9caa50ddbcd2505144e8c3928bc3', 'index': 353}
# {'account': 'paulo21', 'reward_hbd': {'amount': '60', 'nai': '@@000000013', 'precision': 3}, 'reward_hive': {'amount': '0', 'nai': '@@000000021', 'precision': 3}, 'reward_vests': {'amount': '308134017', 'nai': '@@000000037', 'precision': 6}, 'block': 91994034, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2024-12-30T07:25:45', 'trx_id': '6004e5cc7fd78a6915f46a15c4541e634ac324c7', 'trx_in_block': 7, 'virtual_op': False, 'type': 'claim_reward_balance', '_id': 'ed75cf7d317878cd50b37dd964a1192be26c77a1', 'index': 360}
# {'amount': {'amount': '299990', 'nai': '@@000000021', 'precision': 3}, 'from': 'binance-hot2', 'memo': 'STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeKnKu3bwz', 'to': 'paulo21', 'block': 92098804, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2025-01-02T22:50:54', 'trx_id': '10b58a59275c87b7a9567ce07c81eada1ad564fd', 'trx_in_block': 31, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '8e9acf2605b9b07c0733311e536200152c343eaa', 'index': 362}
# {'amount': {'amount': '290000', 'nai': '@@000000021', 'precision': 3}, 'from': 'paulo21', 'memo': '{"id":"ssc-mainnet-hive","json":{"contractName":"hivepegged","contractAction":"buy","contractPayload":{}}}', 'to': 'honey-swap', 'block': 92098828, 'op_in_trx': 0, 'operation_id': 0, 'timestamp': '2025-01-02T22:52:06', 'trx_id': 'f4fef2740d7bc87ddd0dcc6dc9890f812036265d', 'trx_in_block': 0, 'virtual_op': False, 'account': 'paulo21', 'type': 'transfer', '_id': '6af431cff770eb7982552442bac5471b0f7d8c88', 'index': 363}
# Processing transactions except collateral: 100%|██████████| 43/43 [00:01<00:00, 35.80it/s]

# %%
def get_json_transaction_transfer(account_name):

  account = Account(account_name, blockchain_instance=hive)

  total_transactions = len(list(account.history(only_ops=["transfer_from_savings", "transfer_to_savings", "transfer", "claim_reward_balance", "account_create"])))

  transaction_ledger = pd.DataFrame(columns=[    "_date",    "_type",    "_from",    "_memo",    "_to",    "_block",
                                             "_trx_id",    "_id",    "_index",    "_amount_out",    "_amount_in",
                                                 "_currency_out","_currency_in",    "_precision_out",    "_precision_in",
                                                 "_virtual_op", "_key_auths", "_new_account_name"])
  

  for trans in tqdm(account.history(only_ops=["transfer_from_savings", "transfer_to_savings", "transfer", "claim_reward_balance",
                                         "account_create", "custom_json"]), total=total_transactions, desc="Processing transactions except collateral"): #two arguments in the only_ops does not work...

    print(trans)

    # Convert date text to date format
    dateString = trans["timestamp"]
    dateformat = "%Y-%m-%dT%H:%M:%S"

    try:
      _date = datetime.strptime(dateString, dateformat)

    except ValueError:
      _date = "Error parsing date format"

    _type = trans["type"]

    if _type == "custom_json" and trans["id"] == "ssc-mainnet-hive":
      _from = trans["account"]
      try:
        _memo = json.loads(trans["json"])["contractPayload"]["memo"]
      except Exception as e:
        _memo = "Error parsing memo" + str(e)
      _to = json.loads(trans["json"])["contractPayload"]["to"]
      _currency_out = json.loads(trans["json"])["contractPayload"]["symbol"]
      _amount_out = json.loads(trans["json"])["contractPayload"]["quantity"]
      _amount_in = 0
      _block = trans["block"]
      _trx_id = trans["trx_id"]
      _id = trans["_id"]
      _index = trans["index"]
      _currency_in = ""
      _precision_out = 0
      _precision_in = 0
      _virtual_op = trans["virtual_op"]
      _key_auths = "Required auth :" + str(trans["required_auths"])
      _new_account_name = ""

      transaction_ledger.loc[len(transaction_ledger)] = [_date, _type, _from, _memo, _to, _block, _trx_id, _id,
                                                        _index, _amount_out, _amount_in, _currency_out, _currency_in,
                                                        _precision_out, _precision_in, _virtual_op, _key_auths, _new_account_name ]

  return transaction_ledger

# %%
# Sort the DataFrame directly without creating a new one
"""transaction_ledger.sort_values(by='_date', inplace=True)
print(transaction_ledger)"""
# Out:
# "transaction_ledger.sort_values(by='_date', inplace=True)\nprint(transaction_ledger)"

# %%
# Def a function, which extract all transfer type of transaction for an individual account
from tqdm import tqdm

def get_transaction_collateral(account_name):

  account = Account(account_name, blockchain_instance=hive)

  transaction_ledger = pd.DataFrame(columns=[    "_date",    "_type",    "_from",    "_memo",    "_to",    "_block",
                                             "_trx_id",    "_id",    "_index",    "_amount_out",    "_amount_in",
                                                 "_currency_out","_currency_in",    "_precision_out",    "_precision_in",
                                                 "_virtual_op", "_key_auths", "_new_account_name"])

  total_transactions = len(list(account.history()))

  for trans in tqdm(account.history(), total = total_transactions, desc="Processing collateral transactions"): #two arguments in the only_ops does not work...

    # Convert date text to date format
    dateString = trans["timestamp"]
    dateformat = "%Y-%m-%dT%H:%M:%S"

    try:
      _date = datetime.strptime(dateString, dateformat)

    except ValueError:
      _date = "Error parsing date format"

    _type = trans["type"]

    if _type == "fill_collateralized_convert_request":
      _from = trans["account"]
      _memo = ""
      _to = trans["account"]
      _block = trans["block"]
      _trx_id = trans["trx_id"]
      _id = trans["_id"]
      _index = trans["index"]
      _key_auths = ""
      _new_account_name = ""
      _virtual_op = trans["virtual_op"]

      _amount_in = int(trans["amount_in"]["amount"])
      _currency_in = convert_currency(trans["amount_in"]["nai"])
      _precision_in = int(trans["amount_in"]["precision"])
      _amount_in = _amount_in / (10**_precision_in)

      _amount_out = int(trans["amount_out"]["amount"])
      _currency_out = convert_currency(trans["amount_out"]["nai"])
      _precision_out = int(trans["amount_out"]["precision"])

      _excess_collateral = int(trans["excess_collateral"]["amount"])
      _currency_excess_collateral = convert_currency(trans["excess_collateral"]["nai"])
      _precision_excess_collateral = int(trans["excess_collateral"]["precision"])

      if _currency_in == _currency_excess_collateral :
        _currency_in = _currency_in + _currency_excess_collateral
      else :
        _currency_out = _currency_out + _currency_excess_collateral


      transaction_ledger.loc[len(transaction_ledger)] = [_date, _type, _from, _memo, _to, _block, _trx_id, _id,
                                                       _index, _amount_out, _amount_in, _currency_out, _currency_in,
                                                       _precision_out, _precision_in, _virtual_op, _key_auths, _new_account_name ]


    elif _type == "collateralized_convert":
      _from = ""
      _memo = ""
      _to = trans["owner"]
      _block = trans["block"]
      _trx_id = trans["trx_id"]
      _id = trans["_id"]
      _index = trans["index"]
      _key_auths = ""
      _new_account_name = ""
      _virtual_op = trans["virtual_op"]

      _amount_in = 0
      _currency_in = ""
      _precision_in = ""

      _amount_out = int(trans["amount"]["amount"])
      _currency_out = convert_currency(trans["amount"]["nai"])
      _precision_out = int(trans["amount"]["precision"])

      transaction_ledger.loc[len(transaction_ledger)] = [_date, _type, _from, _memo, _to, _block, _trx_id, _id,
                                                       _index, _amount_out, _amount_in, _currency_out, _currency_in,
                                                       _precision_out, _precision_in, _virtual_op, _key_auths, _new_account_name ]


  return transaction_ledger

# %%
def merge_transaction_ledgers(wallet_name):
    """
    Merges two transaction ledgers into a single DataFrame.

    Args:
        transaction_ledger_2: The first transaction ledger (DataFrame).
        transaction_ledger: The second transaction ledger (DataFrame).

    Returns:
        A new DataFrame containing all transactions from both ledgers.
    """
    # Use pd.concat to combine the DataFrames by appending rows

    transaction_ledger_2 = get_transaction_collateral(wallet_name)
    transaction_ledger = get_transaction_transfer(wallet_name)

    merged_ledger = pd.concat([transaction_ledger_2, transaction_ledger], ignore_index=True)
    return merged_ledger

# %%
wallet_name = "ocln-finacct"

transaction_ledger = merge_transaction_ledgers(wallet_name)

#print(transaction_ledger)
# Out:
# Processing collateral transactions: 100%|██████████| 14/14 [00:00<00:00, 14.21it/s]
# Processing transactions except collateral: 0it [00:00, ?it/s]

# %%
# Function : export a pandas DataFrame to an Excel file on a specific folder / path
def export_to_excel(panda_dataframe_data, path_to_folder, file_name):
    """
    Exports a DataFrame to an Excel file.

    Args:
        file_name: The name of the Excel file to create.
        panda_dataframe_data: The DataFrame to export.
    """
    
    # Format the file name
    if not file_name.endswith(".xlsx"):
        file_name += ".xlsx"

    # Create the full file path
    file_path = os.path.join(path_to_folder, file_name)

    # Export the DataFrame to an Excel file
    panda_dataframe_data.to_excel(file_path, index=False)

    print(f"Exported DataFrame to Excel file: {file_name}")

# %%
# Get from HIVE blockchain all transactions from the account "paulo21"
from beem.account import Account
import ast
hive = Hive()
account = Account("paulo21", blockchain_instance=hive)

paulo21_transactions = get_all_account_transactions("paulo21")

print(paulo21_transactions)

file_path = r"C:\Users\triou\iCloudDrive\Personnal Files\Cryptos\Off chain Luxembourg\Accounting\extraction - python"
file_name = "paulo21_transactions"

export_to_excel(paulo21_transactions, file_path, file_name)
# Out:
#                                                 active    creator extensions  \
# 0    {'account_auths': [], 'key_auths': [['STM5dgGu...  leo.voter         []
# 1                                                  NaN  leo.voter        NaN
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 369                                                NaN        NaN        NaN
# 370                                                NaN        NaN        NaN
# 371                                                NaN        NaN        NaN
# 372                                                NaN        NaN        NaN
# 373                                                NaN        NaN        NaN
#
#     json_metadata                                           memo_key  \
# 0              []  STM7ykcBscuDtwoT6xp2gzpvCKukjgAY6EqJ5Li61rmbeK...
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ..            ...                                                ...
# 369           NaN                                                NaN
# 370           NaN                                                NaN
# 371           NaN                                                NaN
# 372           NaN                                                NaN
# 373           NaN                                                NaN
#
#     new_account_name                                              owner  \
# 0            paulo21  {'account_auths': [], 'key_auths': [['STM5hX7H...
# 1            paulo21                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# ..               ...                                                ...
# 369              NaN                                                NaN
# 370              NaN                                                NaN
# 371              NaN                                                NaN
# 372              NaN                                                NaN
# 373              NaN                                                NaN
#
#                                                posting     block  op_in_trx  \
# 0    {'account_auths': [], 'key_auths': [['STM7yxRd...  90507977          0
# 1                                                  NaN  90507977          1
# 2                                                  NaN  90508151          0
# 3                                                  NaN  90509285          0
# 4                                                  NaN  90509710          0
# ..                                                 ...       ...        ...
# 369                                                NaN  92099032          0
# 370                                                NaN  92099044          0
# 371                                                NaN  92099061          0
# 372                                                NaN  92099069          0
# 373                                                NaN  92099074          0
#
#      ...  orderid current_orderid current_owner  current_pays  open_orderid  \
# 0    ...      NaN             NaN           NaN           NaN           NaN
# 1    ...      NaN             NaN           NaN           NaN           NaN
# 2    ...      NaN             NaN           NaN           NaN           NaN
# 3    ...      NaN             NaN           NaN           NaN           NaN
# 4    ...      NaN             NaN           NaN           NaN           NaN
# ..   ...      ...             ...           ...           ...           ...
# 369  ...      NaN             NaN           NaN           NaN           NaN
# 370  ...      NaN             NaN           NaN           NaN           NaN
# 371  ...      NaN             NaN           NaN           NaN           NaN
# 372  ...      NaN             NaN           NaN           NaN           NaN
# 373  ...      NaN             NaN           NaN           NaN           NaN
#
#     open_owner open_pays curator  reward witness
# 0          NaN       NaN     NaN     NaN     NaN
# 1          NaN       NaN     NaN     NaN     NaN
# 2          NaN       NaN     NaN     NaN     NaN
# 3          NaN       NaN     NaN     NaN     NaN
# 4          NaN       NaN     NaN     NaN     NaN
# ..         ...       ...     ...     ...     ...
# 369        NaN       NaN     NaN     NaN     NaN
# 370        NaN       NaN     NaN     NaN     NaN
# 371        NaN       NaN     NaN     NaN     NaN
# 372        NaN       NaN     NaN     NaN     NaN
# 373        NaN       NaN     NaN     NaN     NaN
#
# [374 rows x 94 columns]
# Exported DataFrame to Excel file: paulo21_transactions.xlsx
